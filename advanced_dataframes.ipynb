# %%
from env import get_db_url

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pydataset import data

# %%
# import configparser

# %%
# config = configparser.ConfigParser()
# config.read('config.ini')

# %%
# password = config.get('Credentials', 'password')
# user = config.get('Credentials', 'user')

# %% [markdown]
# # Exercises I

# %% [markdown]
# ## Create a notebook or python script named advanced_dataframes to do your work in for these exercises.

# %% [markdown]
# Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)
# cd into your exercises folder for this module and run echo env.py >> .gitignore
# Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %% [markdown]
# * Use your function to obtain a connection to the employees database.

# %%
url = get_db_url('employees')
pd.read_sql('SELECT * FROM employees', url)
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %% [markdown]
# ### Once you have successfully run a query:

# %% [markdown]
# a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
url = get_db_url('eployees')
pd.read_sql('SELECT * FROM employees', url)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %% [markdown]
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
url = get_db_url('employees')
pd.read_sql('SELECT % FROM employees', url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 url = get_db_url('employees')
# ----> 2 pd.read_sql('SELECT % FROM employees', url)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/pandas/io/sql.py:590, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     581     return pandas_sql.read_table(
#     582         sql,
#     583         index_col=index_col,
#    (...)
#     587         chunksize=chunksize,
#     588     )
#     589 else:
# --> 590     return pandas_sql.read_query(
#     591         sql,
#     592         index_col=index_col,
#     593         params=params,
#     594         coerce_float=coerce_float,
#     595         parse_dates=parse_dates,
#     596         chunksize=chunksize,
#     597     )
#
# ...

# %% [markdown]
# Read the employees and titles tables into two separate DataFrames.

# %%
url = get_db_url('employees')
employees_df = pd.read_sql('SELECT * FROM employees', url)
titles_df = pd.read_sql('SELECT * FROM titles', url)
employees_df
titles_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees_df.shape, titles_df.shape
# Out:
# ((300024, 6), (443308, 4))

# %% [markdown]
# Display the summary statistics for each DataFrame.

# %%
employees_df.describe(), titles_df.describe()
# Out:
# (              emp_no
#  count  300024.000000
#  mean   253321.763392
#  std    161828.235540
#  min     10001.000000
#  25%     85006.750000
#  50%    249987.500000
#  75%    424993.250000
#  max    499999.000000,
#                emp_no
#  count  443308.000000
#  mean   253075.034430
#  std    161853.292613
#  min     10001.000000
#  25%     84855.750000
#  50%    249847.500000
#  75%    424891.250000
#  max    499999.000000)

# %% [markdown]
# How many unique titles are in the titles DataFrame?

# %%
titles_df['title'].nunique()
# Out:
# 7

# %%
titles_df['title'].unique()
# Out:
# array(['Senior Engineer', 'Staff', 'Engineer', 'Senior Staff',
#        'Assistant Engineer', 'Technique Leader', 'Manager'], dtype=object)

# %%
titles_df['title'].value_counts()
# Out:
# Engineer              115003
# Staff                 107391
# Senior Engineer        97750
# Senior Staff           92853
# Technique Leader       15159
# Assistant Engineer     15128
# Manager                   24
# Name: title, dtype: int64

# %% [markdown]
# What is the oldest date in the to_date column?

# %%
titles_df.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %% [markdown]
# What is the most recent date in the to_date column?

# %%
titles_df.to_date.max()
# Out:
# datetime.date(9999, 1, 1)

# %% [markdown]
# # Exercises II

# %% [markdown]
# Copy the users and roles DataFrames from the examples above.

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# What is the result of using a right join on the DataFrames?

# %%
#comapring the two joins (left and right)
users.merge(roles, left_on='role_id', right_on='id', how='inner')
# Out:
#    id_x name_x  role_id  id_y    name_y
# 0     1    bob      1.0     1     admin
# 1     2    joe      2.0     2    author
# 2     3  sally      3.0     3  reviewer
# 3     4   adam      3.0     3  reviewer

# %%
users.merge(roles, left_on='role_id', right_on='id', how='right', indicator=True)
# indicator showd the results of the table
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %% [markdown]
# What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)
# idicator shows the results from joining the two tables
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %% [markdown]
# What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
drop_key_users = users.drop(columns=['role_id'])
drop_key_roles = roles.drop(columns=['id'])

drop_key_users.merge(roles, users, how=inner, indicator=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 4
#       1 drop_key_users = users.drop(columns=['role_id'])
#       2 drop_key_roles = roles.drop(columns=['id'])
# ----> 4 drop_key_users.merge(roles, users, how=inner, indicator=True)
#
# NameError: name 'inner' is not defined

# %% [markdown]
# Load the mpg dataset from PyDataset.

# %%
import pydataset

# %% [markdown]
# Output and read the documentation for the mpg dataset.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data()
#
# NameError: name 'data' is not defined

# %%
mpg_df = data('mpg')
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# How many rows and columns are in the dataset?

# %%
mpg_df.shape
# Out:
# (234, 11)

# %% [markdown]
# Check out your column names and perform any cleanup you may want on them.

# %%
mpg_df = mpg_df.rename(columns={'trans': 'transmission', 'displ': 'displacement', 'drv': 'drive'})
mpg_df
# Out:
#     manufacturer   model  displacement  year  cyl transmission drive  cty  \
# 1           audi      a4           1.8  1999    4     auto(l5)     f   18
# 2           audi      a4           1.8  1999    4   manual(m5)     f   21
# 3           audi      a4           2.0  2008    4   manual(m6)     f   20
# 4           audi      a4           2.0  2008    4     auto(av)     f   21
# 5           audi      a4           2.8  1999    6     auto(l5)     f   16
# ..           ...     ...           ...   ...  ...          ...   ...  ...
# 230   volkswagen  passat           2.0  2008    4     auto(s6)     f   19
# 231   volkswagen  passat           2.0  2008    4   manual(m6)     f   21
# 232   volkswagen  passat           2.8  1999    6     auto(l5)     f   16
# 233   volkswagen  passat           2.8  1999    6   manual(m5)     f   18
# 234   volkswagen  passat           3.6  2008    6     auto(s6)     f   17
#
#      hwy fl    class
# 1     29  p  compact
# 2     29  p  compact
# ...

# %% [markdown]
# Display the summary statistics for the dataset.

# %%
mpg_df.describe()
# Out:
#        displacement         year         cyl         cty         hwy
# count    234.000000   234.000000  234.000000  234.000000  234.000000
# mean       3.471795  2003.500000    5.888889   16.858974   23.440171
# std        1.291959     4.509646    1.611534    4.255946    5.954643
# min        1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%        2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%        3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%        4.600000  2008.000000    8.000000   19.000000   27.000000
# max        7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# How many different manufacturers are there?

# %%
mpg_df.head()
# Out:
#   manufacturer model  displacement  year  cyl transmission drive  cty  hwy fl  \
# 1         audi    a4           1.8  1999    4     auto(l5)     f   18   29  p
# 2         audi    a4           1.8  1999    4   manual(m5)     f   21   29  p
# 3         audi    a4           2.0  2008    4   manual(m6)     f   20   31  p
# 4         audi    a4           2.0  2008    4     auto(av)     f   21   30  p
# 5         audi    a4           2.8  1999    6     auto(l5)     f   16   26  p
#
#      class
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact

# %%
print(f'''There are {len(mpg_df.groupby('manufacturer').count())} manufacturers''')
# Out:
# There are 15 manufacturers

# %% [markdown]
# How many different models are there?

# %%
print(f'''There are {len(mpg_df.groupby('model').count())} models''')
# Out:
# There are 38 models

# %% [markdown]
# Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg_df['mileage_difference'] = (mpg_df.hwy - mpg_df.cty)
mpg_df.head()
# Out:
#   manufacturer model  displacement  year  cyl transmission drive  cty  hwy fl  \
# 1         audi    a4           1.8  1999    4     auto(l5)     f   18   29  p
# 2         audi    a4           1.8  1999    4   manual(m5)     f   21   29  p
# 3         audi    a4           2.0  2008    4   manual(m6)     f   20   31  p
# 4         audi    a4           2.0  2008    4     auto(av)     f   21   30  p
# 5         audi    a4           2.8  1999    6     auto(l5)     f   16   26  p
#
#      class  mileage_difference
# 1  compact                  11
# 2  compact                   8
# 3  compact                  11
# 4  compact                   9
# 5  compact                  10

# %% [markdown]
# Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg_df['average_mileage'] = (mpg_df.hwy + mpg_df.cty) / 2
mpg_df
# Out:
#     manufacturer   model  displacement  year  cyl transmission drive  cty  \
# 1           audi      a4           1.8  1999    4     auto(l5)     f   18
# 2           audi      a4           1.8  1999    4   manual(m5)     f   21
# 3           audi      a4           2.0  2008    4   manual(m6)     f   20
# 4           audi      a4           2.0  2008    4     auto(av)     f   21
# 5           audi      a4           2.8  1999    6     auto(l5)     f   16
# ..           ...     ...           ...   ...  ...          ...   ...  ...
# 230   volkswagen  passat           2.0  2008    4     auto(s6)     f   19
# 231   volkswagen  passat           2.0  2008    4   manual(m6)     f   21
# 232   volkswagen  passat           2.8  1999    6     auto(l5)     f   16
# 233   volkswagen  passat           2.8  1999    6   manual(m5)     f   18
# 234   volkswagen  passat           3.6  2008    6     auto(s6)     f   17
#
#      hwy fl    class  mileage_difference  average_mileage
# ...

# %%
mpg['highwa].agg('mean')

# %% [markdown]
# Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg_df['is_automatic'] = np.where(mpg_df['transmission'].str.contains('auto'), True, False)
# df.loc[df['Name'].str.contains("pokemon", case=False)]

# %% [markdown]
# Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg_df['average_mileage'].max()
# Out:
# 6.0

# %%
mpg_df.head()
# Out:
#   manufacturer model  displacement  year  cyl transmission drive  cty  hwy fl  \
# 1         audi    a4           1.8  1999    4     auto(l5)     f   18   29  p
# 2         audi    a4           1.8  1999    4   manual(m5)     f   21   29  p
# 3         audi    a4           2.0  2008    4   manual(m6)     f   20   31  p
# 4         audi    a4           2.0  2008    4     auto(av)     f   21   30  p
# 5         audi    a4           2.8  1999    6     auto(l5)     f   16   26  p
#
#      class  mileage_difference  average_mileage  is_automatic
# 1  compact                  11             23.5          True
# 2  compact                   8             25.0         False
# 3  compact                  11             25.5         False
# 4  compact                   9             25.5          True
# 5  compact                  10             21.0          True

# %% [markdown]
# Do automatic or manual cars have better miles per gallon?

# %%
mpg_df.groupby('is_automatic').average_mileage.agg(['mean'])
# Out:
#                    mean
# is_automatic
# False         22.227273
# True          19.130573

# %% [markdown]
# # Exercises III

# %% [markdown]
# Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url = get_db_url('chipotle')
orders_df = pd.read_sql('SELECT * FROM orders', url)
orders_df.head(8)
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
# 5   6         3         1                           Chicken Bowl
# 6   7         3         1                          Side of Chips
# 7   8         4         1                          Steak Burrito
#
#                                                                           choice_description  \
# 0                                                                                        nan
# 1                                                                               [Clementine]
# 2                                                                                    [Apple]
# ...

# %% [markdown]
# What is the total price for each order?

# %%
orders_df['item_price'] = orders_df['item_price'].str.replace('$', '')
# Out:
# /var/folders/qh/kjmdb2zx3n3b2ng_n4q3cyn00000gn/T/ipykernel_99401/3641913778.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orders_df['item_price'] = orders_df['item_price'].str.replace('$', '')

# %%
orders_df['item_price'] = pd.to_numeric(orders_df['item_price'], errors='coerce')
orders_df['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
orders_df['total_per_item'] = orders_df.quantity * orders_df.item_price
orders_df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  \
# 0                                                nan        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                nan        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
#
#    total_per_item
# 0            2.39
# 1            3.39
# 2            3.39
# 3            2.39
# 4           33.96

# %%
pd.DataFrame(orders_df.groupby('order_id').total_per_item.sum()).head()
# Out:
#           total_per_item
# order_id
# 1                  11.56
# 2                  33.96
# 3                  12.67
# 4                  21.00
# 5                  13.70

# %% [markdown]
# What are the most popular 3 items?

# %%
orders_df[orders_df.item_name == 'Carnitas Crispy Tacos']
# Out:
#         id  order_id  quantity              item_name  \
# 554    555       230         1  Carnitas Crispy Tacos
# 1008  1009       413         1  Carnitas Crispy Tacos
# 1195  1196       490         1  Carnitas Crispy Tacos
# 1632  1633       658         1  Carnitas Crispy Tacos
# 1838  1839       744         1  Carnitas Crispy Tacos
# 3890  3891      1559         2  Carnitas Crispy Tacos
# 4450  4451      1774         1  Carnitas Crispy Tacos
#
#                                      choice_description  item_price  \
# 554                          [Roasted Chili Corn Salsa]        9.25
# 1008  [Tomatillo Green Chili Salsa, [Rice, Black Bea...       11.75
# 1195  [Tomatillo-Green Chili Salsa (Medium), [Fajita...        8.99
# 1632  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.75
# 1838  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...        8.99
# 3890     [Fresh Tomato Salsa (Mild), [Cheese, Lettuce]]       17.98
# ...

# %%
orders_df.groupby('item_name').count().sort_values(by='id').tail(3)
# Out:
#                       id  order_id  quantity  choice_description  item_price
# item_name
# Chips and Guacamole  479       479       479                 479         479
# Chicken Burrito      553       553       553                 553         553
# Chicken Bowl         726       726       726                 726         726

# %% [markdown]
# Which item has produced the most revenue?

# %%
pd.DataFrame(orders_df.groupby('item_name').sum()['total_per_item'].sort_values(ascending=False).head(1))
# Out:
# /var/folders/qh/kjmdb2zx3n3b2ng_n4q3cyn00000gn/T/ipykernel_99401/1292055373.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(orders_df.groupby('item_name').sum()['total_per_item'].sort_values(ascending=False).head(1))
#               total_per_item
# item_name
# Chicken Bowl         8044.63

# %% [markdown]
# Join the employees and titles DataFrames together.

# %%
url = get_db_url('employees')
employees_df = pd.read_sql('SELECT * FROM employees', url)
titles_df = pd.read_sql('SELECT * FROM titles', url)
employees_df, titles_df
# Out:
# (        emp_no  birth_date first_name last_name gender   hire_date
#  0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
#  1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
#  2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
#  3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
#  4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
#  ...        ...         ...        ...       ...    ...         ...
#  300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
#  300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
#  300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
#  300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
#  300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#  [300024 rows x 6 columns],
#          emp_no            title   from_date     to_date
#  0        10001  Senior Engineer  1986-06-26  9999-01-01
# ...

# %%
employees_merge_df = employees_df.merge(titles_df, left_on='emp_no', right_on='emp_no', how='inner')
employees_merge_df.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
#
#              title   from_date     to_date
# 0  Senior Engineer  1986-06-26  9999-01-01
# 1            Staff  1996-08-03  9999-01-01
# 2  Senior Engineer  1995-12-03  9999-01-01
# 3         Engineer  1986-12-01  1995-12-01
# 4  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# For each title, find the hire date of the employee that was hired most recently with that title.

# %%
employees_merge_df.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
# df.loc[df['Name'].str.contains("pokemon", case=False)]

# %% [markdown]
# Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
query = '''
SELECT t.title,
        de.emp_no,
        d.dept_name,
        t.to_date,
        t.from_date
FROM departments as d
JOIN dept_emp as de
ON emp_no = emp_no
JOIN title as t
ON emp_no = emp_no
'''

# %%
department_titles_df = pd.read_sql(dept_title, get_db_url('employees'))

# %%
department_titles_df.head()
# Out:
#    emp_no         title   from_date     to_date         dept_name
# 0   10011         Staff  1990-01-22  1996-11-09  Customer Service
# 1   10038  Senior Staff  1996-09-20  9999-01-01  Customer Service
# 2   10038         Staff  1989-09-20  1996-09-20  Customer Service
# 3   10049  Senior Staff  2000-05-04  9999-01-01  Customer Service
# 4   10049         Staff  1992-05-04  2000-05-04  Customer Service

# %%
pd.crosstab(department_titles_df.title, department_titles_df.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# ...

# %%
current_emp_df = department_titles_df[department_titles_df.to_date == department_titles_df.to_date.max()]

# %%
current_emp_df.head()
# Out:
#     emp_no         title   from_date     to_date         dept_name
# 1    10038  Senior Staff  1996-09-20  9999-01-01  Customer Service
# 3    10049  Senior Staff  2000-05-04  9999-01-01  Customer Service
# 5    10060  Senior Staff  1996-05-28  9999-01-01  Customer Service
# 7    10088  Senior Staff  1993-09-02  9999-01-01  Customer Service
# 11   10112         Staff  1998-05-01  9999-01-01  Customer Service

# %%
pd.crosstab(current_emp_df.title, current_emp_df.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer                68         1833        0                0
# Engineer                         627        15677        0                0
# Manager                            1            1        1                1
# Senior Engineer                 1790        43364        0                0
# Senior Staff                   12349         1085    10650            10843
# Staff                           3902          315     3199             3416
# Technique Leader                 241         6117        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        1542                 433        77      0
# Engineer                    0       13325                3744       830      0
# Manager                     1           1                   1         1      1
# ...
